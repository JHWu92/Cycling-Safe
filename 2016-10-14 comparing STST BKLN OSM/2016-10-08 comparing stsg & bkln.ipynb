# %% [markdown]
# bkln vs stsg
# questions:
# 1. the relationship between bkln and stsg
# 2. do bkln fill missing stsg on map
#
# or
# 1. Map bkln to stsg

# %%
import geopandas as gp
import pandas as pd
stsg_path = 'dcdata\Street_Segments.geojson'
bkln_path = 'dcdata\Bike_Lane_Street_RightofWay.geojson'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gp_stsg = gp.read_file(stsg_path)
gp_bkln = gp.read_file(bkln_path)
gp_stsg.shape, gp_bkln.shape
# Out:
# ((13522, 22), (1310, 19))

# %%
# gp_bkln[gp_bkln.TRAVELDIRECTION=='In Bound']
gp_bkln.TRAVELDIRECTION.value_counts()
# Out:
#              964
# Out Bound    181
# In Bound     165
# dtype: int64

# %%
gp_bkln = gp_bkln[['OBJECTID','STREETSEGID','geometry','TRAVELDIRECTION']]
gp_stsg = gp_stsg[['OBJECTID','STREETSEGID','geometry']]

# %% [markdown]
# # method 2 for question 1: area of buffered linestring
#
# - buffer lines by 10 meter
# - get area of intersection after buffered
# - calculate the percentage of area overlap, both of bkln and stsg, return the max percentage

# %%
gp_bkln_bfr = gp_bkln.copy()
gp_bkln_bfr.geometry = gp_bkln_bfr.buffer(0.000098)
gp_stsg_bfr = gp_stsg.copy()
gp_stsg_bfr.geometry = gp_stsg_bfr.buffer(0.000098)
bk_st_bfr_sjoin=gp.tools.sjoin(gp_bkln_bfr,gp_stsg_bfr,how='left')
bk_st_bfr_sjoin = bk_st_bfr_sjoin.rename(columns={'geometry':'geometry_left'})

# %%
bk_st_bfr_intrsetn = pd.merge(
    bk_st_bfr_sjoin[['OBJECTID_left','STREETSEGID_left','geometry_left','index_right']],
    gp_stsg_bfr[['STREETSEGID','geometry','OBJECTID']],
    left_on='index_right',right_index = True)
print bk_st_bfr_intrsetn.shape
# Out:
# (8501, 7)
# (1310L,)

# %%
bk_st_bfr_intrsetn['intersection']=bk_st_bfr_intrsetn.apply(lambda x: x.geometry_left.intersection(x.geometry),axis=1)
bk_st_bfr_intrsetn['area'] = bk_st_bfr_intrsetn.intersection.apply(lambda x: x.area)

# %%
def get_area_percentage(x):
    area_left = x.geometry_left.area
    area_right = x.geometry.area
    return x.area/area_left if area_left<area_right else x.area/area_right
bk_st_bfr_intrsetn['area_prcnt'] = bk_st_bfr_intrsetn.apply(get_area_percentage, axis=1)

# %% [markdown]
# ## 5 bklns that do not exist in stsg

# %%
objid_bk_group = {}
# 14857, 15395,  15422
group_name = {'nbk':'new bike lanes', 
              'mbkN1st':'segid matched bike lane N : 1 street segment', 
              '_mbkN1st':'segid not match bike lane N : 1 street segment',
              'm_m':'segid match/not match bk  N : 1 street segment',
              'mbk11st':'segid matched bike lane 1 : 1 street segment',
              '_mbk11st':'segid not match bike lane 1 : 1 street segment',
              '_mbk1Nst':'segid not match bike lane 1 : N street segment',
             }

# %%
bk_st_ovlp = bk_st_bfr_intrsetn[bk_st_bfr_intrsetn.area_prcnt>0.9]
objid_new_bkln = set(gp_bkln.OBJECTID.values) - set(bk_st_ovlp.OBJECTID_left.values)
objid_new_bkln
objid_bk_group['nbk']=set(objid_new_bkln)

# %%
# bk_st_bfr_intrsetn[bk_st_bfr_intrsetn.area_prcnt>0.9].to_csv('bk_st_brf.csv')
print bk_st_ovlp[bk_st_ovlp.STREETSEGID==bk_st_ovlp.STREETSEGID_left].shape
segid_match_bk = bk_st_ovlp[bk_st_ovlp.STREETSEGID==bk_st_ovlp.STREETSEGID_left]
a = segid_match_bk.STREETSEGID_left.value_counts()
segids_bkln_share = a[a>1].index.tolist()
segids_bkln_match = a[a==1].index.tolist()
objid_bk_group['mbkN1st'] = set(segid_match_bk[segid_match_bk.STREETSEGID_left.isin(segids_bkln_share)].OBJECTID_left.tolist())
objid_bk_group['mbk11st'] = set(segid_match_bk[segid_match_bk.STREETSEGID_left.isin(segids_bkln_match)].OBJECTID_left.tolist())
print len(objid_bk_group['mbk11st'])
# Out:
# (1292, 10)
# 1282

# %%
segid_not_match_bk = bk_st_ovlp[bk_st_ovlp.STREETSEGID!=bk_st_ovlp.STREETSEGID_left]

b = segid_not_match_bk.OBJECTID_left.value_counts()
objid_bk_group['_mbk1Nst'] = set(b[b>1].index.tolist())

c = segid_not_match_bk.STREETSEGID_left.value_counts()

segid_bkln_repeat = c[c>1].index.tolist()
bkln_N1_stsg = segid_not_match_bk[segid_not_match_bk.STREETSEGID_left.isin(segid_bkln_repeat) & ~segid_not_match_bk.OBJECTID_left.isin(objid_bkln_multi_stsg)]
objid_bk_group['_mbkN1st'] = set(bkln_N1_stsg.OBJECTID_left.tolist())

objid_bk_group['_mbk11st'] = set(segid_not_match_bk[segid_not_match_bk.STREETSEGID_left.isin(c[c==1].index)].OBJECTID_left.tolist())

objid_bk_group['m_m'] = objid_bk_group['mbk11st'] & objid_bk_group['_mbk11st']

objid_bk_group['mbk11st'] = objid_bk_group['mbk11st'] - objid_bk_group['m_m']
objid_bk_group['_mbk11st'] = objid_bk_group['_mbk11st'] - objid_bk_group['m_m']

# %%
s = 0
for k, v in group_name.items():
    print v, len(objid_bk_group[k])
    s+=len(objid_bk_group[k])
print s
# Out:
# segid matched bike lane 1 : 1 street segment 1281
# segid match/not match bk  N : 1 street segment 1
# segid not match bike lane 1 : N street segment 4
# segid not match bike lane N : 1 street segment 4
# new bike lanes 5
# segid matched bike lane N : 1 street segment 10
# segid not match bike lane 1 : 1 street segment 5
# 1310

# %%
stsg_clr = '#DDEBF7'
gp_stsg['color'] = stsg_clr

group_color = {'nbk':'#FF0000', 
              'mbkN1st':'#FFFF00', 
              '_mbkN1st':'#FFC000',
              'm_m':'#92D050',
              'mbk11st':'#00B050',
              '_mbk11st':'#7030A0',
              '_mbk1Nst':'#0070C0',
            }

# %%
with open('C:\Users\JHW\Desktop\stsg_bkln.js','w') as f:
    for key, objids in objid_bk_group.items():
        gp_df = gp_bkln[gp_bkln.OBJECTID.isin(objids)].copy()
        gp_df['color']=group_color[key]
        js = gp_df.to_json()
        f.write('var %s = %s;\n' % (key, js))
    js_stsg = gp_stsg.to_json()
    f.write('var stsg = %s;\n' % js_stsg)
#     js_bkln = gp_bkln.to_json()
#     f.write('var bkln = %s;\n' % js_bkln)

# %% [markdown]
# # Question 2
# see whether these matches have same STREETSEGID
# - a few bkln overlap with multiple stsg
# -

# %%
print bkln_stsg_intersection.shape
print bkln_stsg_intersection[bkln_stsg_intersection.not_point].shape
bkln_stsg_intersection[bkln_stsg_intersection.not_point].groupby('STREETSEGID_left')['STREETSEGID'].apply(list)
bkln_stsg_intersection[bkln_stsg_intersection.not_point].
# Out:
# (6788, 9)
# (1263, 9)
# STREETSEGID_left
# 0                   [6647]
# 3                      [3]
# 8                      [8]
# 10                    [10]
# 12                    [12]
# 27                    [27]
# 29                    [29]
# 32                    [32]
# 48                    [48]
# 57                    [57]
# 62                    [62]
# 77                    [77]
# 79                    [79]
# 88                    [88]
# 97                    [97]
# 99                    [99]
# 104                  [104]
# 132                  [132]
# 139                  [139]
# 142                  [142]
# 153                  [153]
# 173                  [173]
# 184                  [184]
# 189                  [189]
# 195                  [195]
# 241                  [241]
# 243                  [243]
# 247                  [247]
# 252                  [252]
# 264                  [264]
#                  ...
# 13062              [13062]
# 13069              [13069]
# 13070              [13070]
# 13085              [13085]
# 13091              [13091]
# 13109              [13109]
# 13118              [13118]
# 13123              [13123]
# 13137              [13137]
# 13165              [13165]
# 13185              [13185]
# 13196              [13196]
# 13205              [13205]
# 13221              [13221]
# 13234              [13234]
# 13244              [13244]
# 13253              [13253]
# 13261              [13261]
# 13275              [13275]
# 13281              [13281]
# 13283              [13283]
# 13751       [14532, 14533]
# 14203              [14203]
# 14208              [14208]
# 14259       [14258, 14259]
# 14634              [14634]
# 14787              [14787]
# 14857       [14857, 14858]
# 15422              [11696]
# 16402615            [6090]
# Name: STREETSEGID, dtype: object

# %%
b[b.STREETSEGID==b.STREETSEGID_left]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7e7a5a1a996e> in <module>()
# ----> 1 b[b.STREETSEGID==b.STREETSEGID_left]
#
# NameError: name 'b' is not defined

# %%
b[(b.STREETSEGID==b.STREETSEGID_left)& b.not_point]
# Out:
#       OBJECTID_left  STREETSEGID_left  \
# 0                 1              6816
# 1                 2             11841
# 3                 4              3324
# 175             176              3935
# 2                 3              8839
# 770             771             11188
# 780             781              2783
# 4                 5             12836
# 5                 6             12493
# 6                 7              7336
# 7                 8              8191
# 781             782             10897
# 606             607              7283
# 8                 9              3692
# 604             605              5426
# 9                10              9722
# 10               11              9469
# 502             503             10428
# 503             504              2491
# 11               12              9699
# 12               13              2329
# 458             459                12
# 459             460              9670
# 710             711             12158
# 14               15              4536
# 13               14             12551
# 570             571              9337
# 113             114               676
# 363             364             10325
# 15               16              6014
# ...             ...               ...
# 1264           1265              9923
# 1266           1267              7501
# 1267           1268              3072
# 1268           1269              3155
# 1269           1270             10678
# 1270           1271              5765
# 1271           1272             12273
# 1272           1273              8657
# 1273           1274              8592
# 1274           1275             11991
# 1276           1277             10030
# 1277           1278             12877
# 1278           1279              4983
# 1279           1280              9567
# 1280           1281              3431
# 1290           1291             12270
# 1291           1292              5289
# 1292           1293              9946
# 1297           1298              7135
class 'shapely.geometry.multipoint.MultiPoint'>      True
# 770   <class 'shapely.geometry.collection.GeometryCo...      True
# 780   <class 'shapely.geometry.collection.GeometryCo...      True
# 4     <class 'shapely.geometry.collection.GeometryCo...      True
# 5     <class 'shapely.geometry.multilinestring.Multi...      True
# 6      <class 'shapely.geometry.linestring.LineString'>      True
# 7     <class 'shapely.geometry.multilinestring.Multi...      True
# 781   <class 'shapely.geometry.multilinestring.Multi...      True
# 606   <class 'shapely.geometry.collection.GeometryCo...      True
# 8     <class 'shapely.geometry.multilinestring.Multi...      True
# 604   <class 'shapely.geometry.collection.GeometryCo...      True
# 9      <class 'shapely.geometry.linestring.LineString'>      True
# 10    <class 'shapely.geometry.multilinestring.Multi...      True
# 502   <class 'shapely.geometry.multilinestring.Multi...      True
# 503   <class 'shapely.geometry.collection.GeometryCo...      True
# 11    <class 'shapely.geometry.collection.GeometryCo...      True
# 12    <class 'shapely.geometry.collection.GeometryCo...      True
# 458   <class 'shapely.geometry.multilinestring.Multi...      True
# 459   <class 'shapely.geometry.multilinestring.Multi...      True
# 710   <class 'shapely.geometry.multilinestring.Multi...      True
# 14    <class 'shapely.geometry.multilinestring.Multi...      True
# 13    <class 'shapely.geometry.multilinestring.Multi...      True
# 570   <class 'shapely.geometry.multilinestring.Multi...      True
# 113   <class 'shapely.geometry.multilinestring.Multi...      True
# 363   <class 'shapely.geometry.collection.GeometryCo...      True
# 15    <class 'shapely.geometry.collection.GeometryCo...      True
# ...                                                 ...       ...
# 1264  <class 'shapely.geometry.multilinestring.Multi...      True
# 1266  <class 'shapely.geometry.multilinestring.Multi...      True
# 1267  <class 'shapely.geometry.collection.GeometryCo...      True
# 1268  <class 'shapely.geometry.multilinestring.Multi...      True
# 1269  <class 'shapely.geometry.multilinestring.Multi...      True
# 1270  <class 'shapely.geometry.multilinestring.Multi...      True
# 1271  <class 'shapely.geometry.collection.GeometryCo...      True
# 1272  <class 'shapely.geometry.multilinestring.Multi...      True
# 1273  <class 'shapely.geometry.collection.GeometryCo...      True
# 1274  <class 'shapely.geometry.collection.GeometryCo...      True
# 1276  <class 'shapely.geometry.multilinestring.Multi...      True
# 1277  <class 'shapely.geometry.collection.GeometryCo...      True
# 1278  <class 'shapely.geometry.multilinestring.Multi...      True
# 1279  <class 'shapely.geometry.multilinestring.Multi...      True
# 1280   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1290   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1291   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1292   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1297   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1298   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1299   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1300  <class 'shapely.geometry.collection.GeometryCo...      True
# 1301   <class 'shapely.geometry.linestring.LineString'>      True
# 1302   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1303   <class 'shapely.geometry.multipoint.MultiPoint'>      True
# 1304  <class 'shapely.geometry.multilinestring.Multi...      True
# 1307  <class 'shapely.geometry.collection.GeometryCo...      True
# 1306  <class 'shapely.geometry.multilinestring.Multi...      True
# 1309  <class 'shapely.geometry.multilinestring.Multi...      True
# 1308  <class 'shapely.geometry.collection.GeometryCo...      True
#
# [1244 rows x 10 columns]

# %%
b[~(b.STREETSEGID==b.STREETSEGID_left)& b.not_point].OBJECTID_left.value_counts()
# Out:
# 281     3
# 859     2
# 535     2
# 962     2
# 1274    1
# 1175    1
# 565     1
# 274     1
# 1297    1
# 336     1
# 1165    1
# 684     1
# 199     1
# 1221    1
# dtype: int64

# %%
281     3
859     2
535     2
962     2
1274    2
1175    2
274     2
336     2
